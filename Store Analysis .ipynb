# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Loading the data

# %%
df = pd.read_csv("stores.csv")
df
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0            1        1659             1961                   530        66490
# 1            2        1461             1752                   210        39820
# 2            3        1340             1609                   720        54010
# 3            4        1451             1748                   620        53730
# 4            5        1770             2111                   450        46620
# ..         ...         ...              ...                   ...          ...
# 891        892        1582             1910                  1080        66390
# 892        893        1387             1663                   850        82080
# 893        894        1200             1436                  1060        76440
# 894        895        1299             1560                   770        96610
# 895        896        1174             1429                  1110        54340
#
# [896 rows x 5 columns]

# %% [markdown]
# # Data Preprocessing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 896 entries, 0 to 895
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Store ID              896 non-null    int64
#  1   Store_Area            896 non-null    int64
#  2   Items_Available       896 non-null    int64
#  3   Daily_Customer_Count  896 non-null    int64
#  4   Store_Sales           896 non-null    int64
# dtypes: int64(5)
# memory usage: 35.1 KB

# %%
df.describe().T
# Out:
#                       count          mean           std      min       25%  \
# Store ID              896.0    448.500000    258.797218      1.0    224.75
# Store_Area            896.0   1485.409598    250.237011    775.0   1316.75
# Items_Available       896.0   1782.035714    299.872053    932.0   1575.50
# Daily_Customer_Count  896.0    786.350446    265.389281     10.0    600.00
# Store_Sales           896.0  59351.305804  17190.741895  14920.0  46530.00
#
#                           50%       75%       max
# Store ID                448.5    672.25     896.0
# Store_Area             1477.0   1653.50    2229.0
# Items_Available        1773.5   1982.75    2667.0
# Daily_Customer_Count    780.0    970.00    1560.0
# Store_Sales           58605.0  71872.50  116320.0

# %%
df.shape
# Out:
# (896, 5)

# %%
pip install autoviz
# Out:
# Collecting autoviz
#   Downloading autoviz-0.1.41-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.1 MB/s eta 0:00:011
# Requirement already satisfied: pandas in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from autoviz) (1.3.4)
# Collecting typing-extensions>=4.1.1
#   Downloading typing_extensions-4.3.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: fsspec>=0.8.3 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from autoviz) (2021.8.1)
# Collecting emoji
#   Downloading emoji-1.7.0.tar.gz (175 kB)
#      |████████████████████████████████| 175 kB 2.2 MB/s eta 0:00:01
# Collecting bokeh>=2.4.2
#   Downloading bokeh-2.4.3-py3-none-any.whl (18.5 MB)
#      |████████████████████████████████| 18.5 MB 3.9 MB/s eta 0:00:01
# Collecting xgboost>=0.82
#   Downloading xgboost-1.6.1-py3-none-macosx_10_15_x86_64.macosx_11_0_x86_64.macosx_12_0_x86_64.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 2.8 MB/s eta 0:00:01
# Requirement already satisfied: statsmodels in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from autoviz) (0.12.2)
# Collecting textblob
#   Downloading textblob-0.17.1-py2.py3-none-any.whl (636 kB)
#      |████████████████████████████████| 636 kB 2.9 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from autoviz) (1.20.3)
# Requirement already satisfied: matplotlib>=3.3.3 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from autoviz) (3.4.3)
# Requirement already satisfied: ipython in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from autoviz) (7.29.0)
# Collecting holoviews>=1.14.6
#   Downloading holoviews-1.14.9-py2.py3-none-any.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 1.9 MB/s eta 0:00:01     |██████████████████████▋         | 3.0 MB 4.2 MB/s eta 0:00:01
# Collecting wordcloud
#   Downloading wordcloud-1.8.2.2-cp39-cp39-macosx_10_9_x86_64.whl (160 kB)
#      |████████████████████████████████| 160 kB 2.0 MB/s eta 0:00:01
# Requirement already satisfied: jupyter in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from autoviz) (1.0.0)
# Requirement already satisfied: xlrd in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from autoviz) (2.0.1)
# Requirement already satisfied: scikit-learn in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from autoviz) (0.24.2)
# Collecting hvplot>=0.7.3
#   Downloading hvplot-0.8.0-py2.py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 2.0 MB/s eta 0:00:01
# Requirement already satisfied: seaborn>=0.11.1 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from autoviz) (0.11.2)
# Requirement already satisfied: nltk in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from autoviz) (3.6.5)
# Collecting pyamg
#   Downloading pyamg-4.2.3-cp39-cp39-macosx_10_9_x86_64.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 831 kB/s eta 0:00:01
# Collecting panel~=0.12.6
#   Downloading panel-0.12.7-py2.py3-none-any.whl (12.9 MB)
#      |████████████████████████████████| 12.9 MB 3.4 MB/s eta 0:00:01
# Requirement already satisfied: PyYAML>=3.10 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from bokeh>=2.4.2->autoviz) (6.0)
# Requirement already satisfied: tornado>=5.1 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from bokeh>=2.4.2->autoviz) (6.1)
# Requirement already satisfied: pillow>=7.1.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from bokeh>=2.4.2->autoviz) (8.4.0)
# Requirement already satisfied: packaging>=16.8 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from bokeh>=2.4.2->autoviz) (21.0)
# Requirement already satisfied: Jinja2>=2.9 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from bokeh>=2.4.2->autoviz) (2.11.3)
# Collecting colorcet
#   Downloading colorcet-3.0.0-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 5.1 MB/s eta 0:00:01
# Collecting param<2.0,>=1.9.3
#   Downloading param-1.12.2-py2.py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 3.9 MB/s eta 0:00:01
# Collecting pyviz-comms>=0.7.4
#   Downloading pyviz_comms-2.2.0-py2.py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 2.4 MB/s eta 0:00:01
# Collecting pyct>=0.4.4
#   Downloading pyct-0.4.8-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from Jinja2>=2.9->bokeh>=2.4.2->autoviz) (1.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.3.3->autoviz) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.3.3->autoviz) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.3.3->autoviz) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.3.3->autoviz) (1.3.1)
# Requirement already satisfied: six in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib>=3.3.3->autoviz) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from pandas->autoviz) (2021.3)
# Requirement already satisfied: tqdm>=4.48.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from panel~=0.12.6->autoviz) (4.62.3)
# Requirement already satisfied: requests in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from panel~=0.12.6->autoviz) (2.26.0)
# Requirement already satisfied: bleach in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from panel~=0.12.6->autoviz) (4.0.0)
# Requirement already satisfied: setuptools<61,>=42 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from panel~=0.12.6->autoviz) (58.0.4)
# Collecting markdown
#   Downloading Markdown-3.3.7-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 3.7 MB/s eta 0:00:01
# Requirement already satisfied: scipy>=1.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from seaborn>=0.11.1->autoviz) (1.7.1)
# Requirement already satisfied: webencodings in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from bleach->panel~=0.12.6->autoviz) (0.5.1)
# Requirement already satisfied: pickleshare in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from ipython->autoviz) (0.7.5)
# Requirement already satisfied: matplotlib-inline in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from ipython->autoviz) (0.1.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from ipython->autoviz) (3.0.20)
# Requirement already satisfied: traitlets>=4.2 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from ipython->autoviz) (5.1.0)
# Requirement already satisfied: appnope in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from ipython->autoviz) (0.1.2)
# Requirement already satisfied: decorator in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from ipython->autoviz) (5.1.0)
# Requirement already satisfied: jedi>=0.16 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from ipython->autoviz) (0.18.0)
# Requirement already satisfied: pygments in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from ipython->autoviz) (2.10.0)
# Requirement already satisfied: backcall in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from ipython->autoviz) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from ipython->autoviz) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython->autoviz) (0.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython->autoviz) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->autoviz) (0.2.5)
# Requirement already satisfied: ipywidgets in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from jupyter->autoviz) (7.6.5)
# Requirement already satisfied: qtconsole in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from jupyter->autoviz) (5.1.1)
# Requirement already satisfied: nbconvert in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from jupyter->autoviz) (6.1.0)
# Requirement already satisfied: notebook in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from jupyter->autoviz) (6.4.5)
# Requirement already satisfied: ipykernel in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from jupyter->autoviz) (6.4.1)
# Requirement already satisfied: jupyter-console in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from jupyter->autoviz) (6.4.0)
# Requirement already satisfied: ipython-genutils in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->jupyter->autoviz) (0.2.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->jupyter->autoviz) (1.4.1)
# Requirement already satisfied: jupyter-client<8.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->jupyter->autoviz) (6.1.12)
# Requirement already satisfied: pyzmq>=13 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel->jupyter->autoviz) (22.2.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel->jupyter->autoviz) (4.8.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets->jupyter->autoviz) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets->jupyter->autoviz) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets->jupyter->autoviz) (3.5.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->autoviz) (3.2.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->autoviz) (21.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->autoviz) (0.18.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from notebook->jupyter->autoviz) (1.8.0)
# Requirement already satisfied: prometheus-client in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from notebook->jupyter->autoviz) (0.11.0)
# Requirement already satisfied: argon2-cffi in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from notebook->jupyter->autoviz) (20.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from notebook->jupyter->autoviz) (0.9.4)
# Requirement already satisfied: cffi>=1.0.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from argon2-cffi->notebook->jupyter->autoviz) (1.14.6)
# Requirement already satisfied: pycparser in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->notebook->jupyter->autoviz) (2.20)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from markdown->panel~=0.12.6->autoviz) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown->panel~=0.12.6->autoviz) (3.6.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->jupyter->autoviz) (0.5.3)
# Requirement already satisfied: defusedxml in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->jupyter->autoviz) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->jupyter->autoviz) (1.4.3)
# Requirement already satisfied: jupyterlab-pygments in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->jupyter->autoviz) (0.1.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->jupyter->autoviz) (0.3)
# Requirement already satisfied: testpath in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->jupyter->autoviz) (0.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->jupyter->autoviz) (0.8.4)
# Requirement already satisfied: nest-asyncio in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter->autoviz) (1.5.1)
# Requirement already satisfied: async-generator in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter->autoviz) (1.10)
# Requirement already satisfied: click in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from nltk->autoviz) (8.0.3)
# Requirement already satisfied: joblib in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from nltk->autoviz) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from nltk->autoviz) (2021.8.3)
# Requirement already satisfied: qtpy in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from qtconsole->jupyter->autoviz) (1.10.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from requests->panel~=0.12.6->autoviz) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from requests->panel~=0.12.6->autoviz) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from requests->panel~=0.12.6->autoviz) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from requests->panel~=0.12.6->autoviz) (1.26.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->autoviz) (2.2.0)
# Requirement already satisfied: patsy>=0.5 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from statsmodels->autoviz) (0.5.2)
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171047 sha256=9e1a94af78f0841287b53ca7c224cdd70820651ca4828b414912519e4196d18f
#   Stored in directory: /Users/hariharanmuniandy/Library/Caches/pip/wheels/fa/7a/e9/22dd0515e1bad255e51663ee513a2fa839c95934c5fc301090
# Successfully built emoji
# Installing collected packages: typing-extensions, param, pyviz-comms, pyct, markdown, bokeh, panel, colorcet, holoviews, xgboost, wordcloud, textblob, pyamg, hvplot, emoji, autoviz
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.2
#     Uninstalling typing-extensions-3.10.0.2:
#       Successfully uninstalled typing-extensions-3.10.0.2
#   Attempting uninstall: bokeh
#     Found existing installation: bokeh 2.4.1
#     Uninstalling bokeh-2.4.1:
#       Successfully uninstalled bokeh-2.4.1
# Successfully installed autoviz-0.1.41 bokeh-2.4.3 colorcet-3.0.0 emoji-1.7.0 holoviews-1.14.9 hvplot-0.8.0 markdown-3.3.7 panel-0.12.7 param-1.12.2 pyamg-4.2.3 pyct-0.4.8 pyviz-comms-2.2.0 textblob-0.17.1 typing-extensions-4.3.0 wordcloud-1.8.2.2 xgboost-1.6.1
# Note: you may need to restart the kernel to use updated packages.

# %%
#importing Autoviz class
from autoviz.AutoViz_Class import AutoViz_Class#Instantiate the AutoViz class
AV = AutoViz_Class()

# %%
df = AV.AutoViz('stores.csv')
# Out:
# Shape of your Data Set loaded: (896, 5)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     5 Predictors classified...
#         1 variables removed since they were ID or low-information variables
# Number of All Scatter Plots = 10
# No categorical or numeric vars in data set. Hence no bar charts.
# Time to run AutoViz = 3 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################

# %%
df
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0            1        1659             1961                   530        66490
# 1            2        1461             1752                   210        39820
# 2            3        1340             1609                   720        54010
# 3            4        1451             1748                   620        53730
# 4            5        1770             2111                   450        46620
# ..         ...         ...              ...                   ...          ...
# 891        892        1582             1910                  1080        66390
# 892        893        1387             1663                   850        82080
# 893        894        1200             1436                  1060        76440
# 894        895        1299             1560                   770        96610
# 895        896        1174             1429                  1110        54340
#
# [896 rows x 5 columns]

# %%
import lux
import pandas as pd
df = pd.read_csv("stores.csv")
df
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
pip install lux
# Out:
# Collecting lux
#   Downloading lux-0.5.1.tar.gz (14 kB)
# Collecting lux-api
#   Downloading lux-api-0.5.1.tar.gz (127 kB)
#      |████████████████████████████████| 127 kB 1.7 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting lux-widget
#   Downloading lux-widget-0.1.11.tar.gz (2.5 MB)
#      |████████████████████████████████| 2.5 MB 69 kB/s eta 0:00:012
# Requirement already satisfied: autopep8>=1.5 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from lux-api->lux) (1.5.7)
# Requirement already satisfied: scikit-learn>=0.22 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from lux-api->lux) (0.24.2)
# Requirement already satisfied: scipy>=1.3.3 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from lux-api->lux) (1.7.1)
# Collecting psutil>=5.9.0
#   Downloading psutil-5.9.1-cp39-cp39-macosx_10_9_x86_64.whl (239 kB)
#      |████████████████████████████████| 239 kB 901 kB/s eta 0:00:01
# Collecting sh
#   Downloading sh-1.14.2-py2.py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 3.0 MB/s eta 0:00:01
# Requirement already satisfied: pandas in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from lux-api->lux) (1.3.4)
# Requirement already satisfied: numpy>=1.16.5 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from lux-api->lux) (1.20.3)
# Requirement already satisfied: matplotlib>=3.0.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from lux-api->lux) (3.4.3)
# Collecting altair>=4.0.0
#   Downloading altair-4.2.0-py3-none-any.whl (812 kB)
#      |████████████████████████████████| 812 kB 2.4 MB/s eta 0:00:01
# Collecting iso3166
#   Downloading iso3166-2.0.2-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: toolz in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from altair>=4.0.0->lux-api->lux) (0.11.1)
# Requirement already satisfied: entrypoints in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from altair>=4.0.0->lux-api->lux) (0.3)
# Requirement already satisfied: jsonschema>=3.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from altair>=4.0.0->lux-api->lux) (3.2.0)
# Requirement already satisfied: jinja2 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from altair>=4.0.0->lux-api->lux) (2.11.3)
# Requirement already satisfied: pycodestyle>=2.7.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from autopep8>=1.5->lux-api->lux) (2.7.0)
# Requirement already satisfied: toml in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from autopep8>=1.5->lux-api->lux) (0.10.2)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api->lux) (0.18.0)
# Requirement already satisfied: setuptools in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api->lux) (58.0.4)
# Requirement already satisfied: attrs>=17.4.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api->lux) (21.2.0)
# Requirement already satisfied: six>=1.11.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api->lux) (1.16.0)
# Requirement already satisfied: notebook>=4.0.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from lux-widget->lux) (6.4.5)
# Requirement already satisfied: ipywidgets>=7.5.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from lux-widget->lux) (7.6.5)
# Requirement already satisfied: ipython>=4.0.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.5.0->lux-widget->lux) (7.29.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.5.0->lux-widget->lux) (6.4.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.5.0->lux-widget->lux) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.5.0->lux-widget->lux) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.5.0->lux-widget->lux) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.5.0->lux-widget->lux) (3.5.1)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.5.0->lux-widget->lux) (5.1.0)
# Requirement already satisfied: jupyter-client<8.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget->lux) (6.1.12)
# Requirement already satisfied: appnope in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget->lux) (0.1.2)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget->lux) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget->lux) (1.4.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget->lux) (6.1)
# Requirement already satisfied: jedi>=0.16 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (0.18.0)
# Requirement already satisfied: decorator in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (5.1.0)
# Requirement already satisfied: pexpect>4.3 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (4.8.0)
# Requirement already satisfied: pickleshare in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (3.0.20)
# Requirement already satisfied: pygments in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (2.10.0)
# Requirement already satisfied: backcall in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (0.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget->lux) (4.8.1)
# Requirement already satisfied: pyzmq>=13 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget->lux) (22.2.1)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget->lux) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->lux-api->lux) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->lux-api->lux) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->lux-api->lux) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->lux-api->lux) (0.10.0)
# Requirement already satisfied: nbconvert in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.0.0->lux-widget->lux) (6.1.0)
# Requirement already satisfied: prometheus-client in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.0.0->lux-widget->lux) (0.11.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.0.0->lux-widget->lux) (0.9.4)
# Requirement already satisfied: argon2-cffi in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.0.0->lux-widget->lux) (20.1.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.0.0->lux-widget->lux) (1.8.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from pandas->lux-api->lux) (2021.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (0.2.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.22->lux-api->lux) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.22->lux-api->lux) (1.1.0)
# Requirement already satisfied: cffi>=1.0.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.0.0->lux-widget->lux) (1.14.6)
# Requirement already satisfied: pycparser in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.0.0->lux-widget->lux) (2.20)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from jinja2->altair>=4.0.0->lux-api->lux) (1.1.1)
# Requirement already satisfied: defusedxml in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.0.0->lux-widget->lux) (0.7.1)
# Requirement already satisfied: bleach in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.0.0->lux-widget->lux) (4.0.0)
# Requirement already satisfied: jupyterlab-pygments in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.0.0->lux-widget->lux) (0.1.2)
# Requirement already satisfied: testpath in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.0.0->lux-widget->lux) (0.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.0.0->lux-widget->lux) (0.5.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.0.0->lux-widget->lux) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.0.0->lux-widget->lux) (1.4.3)
# Requirement already satisfied: async-generator in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.0.0->lux-widget->lux) (1.10)
# Requirement already satisfied: nest-asyncio in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.0.0->lux-widget->lux) (1.5.1)
# Requirement already satisfied: packaging in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.0.0->lux-widget->lux) (21.0)
# Requirement already satisfied: webencodings in /Users/hariharanmuniandy/opt/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.0.0->lux-widget->lux) (0.5.1)
# Building wheels for collected packages: lux, lux-api, lux-widget
#   Building wheel for lux (setup.py) ... done
#   Created wheel for lux: filename=lux-0.5.1-py3-none-any.whl size=11979 sha256=ce5c2036246e2799d5b1069bc372cd3c6804cc552ed437236667e24a45acf3ff
#   Stored in directory: /Users/hariharanmuniandy/Library/Caches/pip/wheels/eb/1a/ea/63737a35e77092f9238a1b023851b69f34270754063317527d
#   Building wheel for lux-api (PEP 517) ... done
#   Created wheel for lux-api: filename=lux_api-0.5.1-py3-none-any.whl size=185610 sha256=879a399ffcb268135551b6426f1e0a10a255253c5461c442e72ac0b8fd9efdfe
#   Stored in directory: /Users/hariharanmuniandy/Library/Caches/pip/wheels/bd/05/a4/441d23d1cece85d6cd3cec43b38896e88a729e8048138825bd
#   Building wheel for lux-widget (setup.py) ... done
#   Created wheel for lux-widget: filename=lux_widget-0.1.11-py3-none-any.whl size=2540458 sha256=ef9ef094dd02b296577d29330d4be18b56bcb2f4fa18b90bca0e4a6db4d1183b
#   Stored in directory: /Users/hariharanmuniandy/Library/Caches/pip/wheels/03/dd/c3/286c3ca89a08533a99b0eb3f6e9a4b4c23476202c5a3fd622e
# Successfully built lux lux-api lux-widget
# Installing collected packages: sh, psutil, lux-widget, iso3166, altair, lux-api, lux
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.8.0
#     Uninstalling psutil-5.8.0:
#       Successfully uninstalled psutil-5.8.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.1.5 requires pyqt5<5.13, which is not installed.
# spyder 5.1.5 requires pyqtwebengine<5.13, which is not installed.
# Successfully installed altair-4.2.0 iso3166-2.0.2 lux-0.5.1 lux-api-0.5.1 lux-widget-0.1.11 psutil-5.9.1 sh-1.14.2
# Note: you may need to restart the kernel to use updated packages.
